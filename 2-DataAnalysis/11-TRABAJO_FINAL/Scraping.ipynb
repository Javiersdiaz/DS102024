# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.madrid.es/portales/munimadrid/es/Inicio/El-Ayuntamiento/Cultura-y-Ocio/Actividades-Infantiles"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# Buscar tarjetas de eventos
eventos = soup.select(".detalle-evento")  # Cambia según el HTML real

for e in eventos:
    titulo = e.select_one("h3")  # Suponiendo que el título está en un <h3>
    if titulo:
        print(titulo.text.strip())

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time

# Configurar el navegador
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.madrid.es/portales/munimadrid/es/Inicio/Cultura-ocio-y-deporte/Actividades-infantiles/?vgnextchannel=7911f073808fe410VgnVCM2000000c205a0aRCRD")

# Esperar a que cargue el contenido
time.sleep(5)

# Extraer información de las actividades
eventos = driver.find_elements(By.CLASS_NAME, "elementoAgenda")

for evento in eventos:
    try:
        nombre = evento.find_element(By.CLASS_NAME, "title").text
    except:
        nombre = "No disponible"

    try:
        fecha = evento.find_element(By.CLASS_NAME, "fechaAgenda").text
    except:
        fecha = "No disponible"

    try:
        lugar = evento.find_element(By.CLASS_NAME, "lugarAgenda").text
    except:
        lugar = "No disponible"

    try:
        detalles = evento.find_element(By.CLASS_NAME, "resumen").text
    except:
        detalles = "No disponible"

    print(f"🎨 Evento: {nombre}")
    print(f"📅 Fecha: {fecha}")
    print(f"📍 Lugar: {lugar}")
    print(f"📝 Detalles: {detalles}")
    print("------")

driver.quit()
