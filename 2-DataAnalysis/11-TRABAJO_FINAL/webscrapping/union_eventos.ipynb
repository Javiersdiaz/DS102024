# %%
import numpy as np
import pandas as pd
import matplotlib as mlt
import seaborn as sns

# %%
df = pd.read_csv('actividades_familiares_españa_v9.csv')
df
# Out:
#                                         nombre_evento     ciudad       fecha  \
# 0                      Museo de la Ciencia Valladolid       Otro  2025-02-25
# 1                         Pueblo Español de Barcelona  Barcelona  2025-07-04
# 2               Museo Interactivo de la Música Málaga     Málaga  2025-07-05
# 3                               Museo Naval de Madrid     Madrid  2025-02-25
# 4                                    Dinópolis Teruel       Otro  2025-04-25
# 5      Safari Madrid: un viaje salvaje desde tu coche     Madrid  2025-05-09
# 6   Caixabank Madrid live experience 2025: música ...     Madrid  2025-07-09
# 7   El pequeño Mozart: música clásica para niños e...       Otro  2025-07-13
# 8   Mira las estrellas con tu familia desde el Noc...       Otro  2025-09-22
# 9    Planes con niños para el fin de semana en Madrid       Otro  2025-10-20
# 10  Talleres en CaixaForum Madrid: actividades cre...    Sevilla  2025-07-04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   nombre_evento  36 non-null     object
#  1   Imagen         36 non-null     object
#  2   categoria      36 non-null     object
#  3   ciudad         36 non-null     object
#  4   descripcion    36 non-null     object
# dtypes: object(5)
# memory usage: 1.5+ KB

# %%
df.isna().sum()
# Out:
# id_evento             0
# nombre_evento         0
# ubicacion             0
# fecha                 0
# categoria             0
# necesidad_especial    0
# integrantes           0
# edad_minima           0
# modalidad             0
# precio                0
# link                  0
# descripcion           0
# dtype: int64

# %%
df['categoria'].unique()
# Out:
# array(['Espectáculo', 'Concierto', 'Exposición', 'Festival', 'Museo',
#        'Parque Temático', 'Literatura'], dtype=object)

# %%
df['integrantes'].unique()
# Out:
# array([5, 3, 1, 2, 4])

# %%
df['precio'].unique()
# Out:
# array(['Por confirmar', 'Desde 10€', 'Desde 20€', 'Desde 30€', 'Gratis',
#        'Desde 5€'], dtype=object)

# %%
df['ubicacion'].unique()
# Out:
# array(['Valladolid', 'Barcelona', 'Málaga', 'Madrid', 'Teruel',
#        'Albacete', 'Cádiz', 'Asturias', 'Illes Balears', 'Valencia',
#        'Bizkaia', 'Cantabria', 'A Coruña', 'Sevilla', 'Badajoz', 'Lleida',
#        'Ciudad Real', 'Guadalajara'], dtype=object)

# %%
df['descripcion'].unique()
# Out:
# array(['Actividad: Museo de la Ciencia Valladolid | Categoría: Espectáculo | Fecha: 25/02/2025 | Ubicación: Valladolid',
#        'Actividad: Pueblo Español de Barcelona | Categoría: Concierto | Fecha: 04/07/2025 | Ubicación: Barcelona',
#        'Actividad: Museo Interactivo de la Música Málaga | Categoría: Espectáculo | Fecha: 05/07/2025 | Ubicación: Málaga',
#        ...,
#        'Actividad: Harpia Balaguer Medieval Lleida | Categoría: Literatura | Fecha: 23/10/2025 | Ubicación: Lleida',
#        'Actividad: Festival de los Sentidos Albacete | Categoría: Festival | Fecha: 03/12/2025 | Ubicación: Albacete',
#        'Actividad: Atlantis Aquarium Madrid | Categoría: Espectáculo | Fecha: 25/06/2025 | Ubicación: Aquarium Madrid'],
#       shape=(7361,), dtype=object)
