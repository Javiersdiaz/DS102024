# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
df =pd.read_parquet('train.parquet')
df.head(5)
# Out:
#      id      class cap_shape cap_surface cap_color    odor gill_attachment  \
# 0   367     edible      bell       scaly    yellow  almond            free
# 1  5123  poisonous    convex      smooth       red    foul            free
# 2  2864     edible    convex     fibrous     green    null            free
# 3  4674  poisonous      flat      smooth     white    foul            free
# 4  1210     edible    convex      smooth     white    null            free
#
#   gill_spacing gill_size gill_color  ... stalk_color_above_ring  \
# 0        close     broad      black  ...                  white
# 1        close    narrow       buff  ...                  white
# 2        close     broad       pink  ...                   pink
# 3        close     broad       pink  ...                  white
# 4      crowded     broad      black  ...                  white
#
#   stalk_color_below_ring veil_type veil_color ring_number   ring_type  \
# 0                  white   partial      white         one     pendant
# 1                   pink   partial      white         one  evanescent
# 2                  white   partial      white         one     pendant
# 3                  white   partial      white         one     pendant
# 4                  white   partial      white         one  evanescent
#
#   spore_print_color population  habitat      bruises
# 0             brown  scattered  grasses      Bruises
# 1             white    several    paths  No presenta
# 2             brown    several     wood      Bruises
# 3         chocolate  scattered  grasses      Bruises
# 4             black   abundant  grasses  No presenta
#
# [5 rows x 24 columns]

# %%
df = df.set_index('id')
df.head()
# Out:
#           class cap_shape cap_surface cap_color    odor gill_attachment  \
# id
# 367      edible      bell       scaly    yellow  almond            free
# 5123  poisonous    convex      smooth       red    foul            free
# 2864     edible    convex     fibrous     green    null            free
# 4674  poisonous      flat      smooth     white    foul            free
# 1210     edible    convex      smooth     white    null            free
#
#      gill_spacing gill_size gill_color stalk_shape  ...  \
# id                                                  ...
# 367         close     broad      black   enlarging  ...
# 5123        close    narrow       buff    tapering  ...
# 2864        close     broad       pink    tapering  ...
# 4674        close     broad       pink    tapering  ...
# 1210      crowded     broad      black    tapering  ...
#
#      stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# id
# 367                   white                  white   partial      white
# 5123                  white                   pink   partial      white
# 2864                   pink                  white   partial      white
# 4674                  white                  white   partial      white
# 1210                  white                  white   partial      white
#
#      ring_number   ring_type spore_print_color population  habitat  \
# id
# 367          one     pendant             brown  scattered  grasses
# 5123         one  evanescent             white    several    paths
# 2864         one     pendant             brown    several     wood
# 4674         one     pendant         chocolate  scattered  grasses
# 1210         one  evanescent             black   abundant  grasses
#
#           bruises
# id
# 367       Bruises
# 5123  No presenta
# 2864      Bruises
# 4674      Bruises
# 1210  No presenta
#
# [5 rows x 23 columns]

# %%
df['cap_shape'].unique()
# Out:
# array(['bell', 'convex', 'flat', 'sunken', 'knobbed', 'c'], dtype=object)

# %%
df['class'] = df['class'].map({'edible': 1, 'poisonous': 0})
df['gill_attachment'] = df['gill_attachment'].map({'free': 1, 'attached': 0 })
df['stalk_shape'] = df['stalk_shape'].map({'enlarging': 1, 'tapering': 0})
df['veil_type'] = df['veil_type'].map({'partial': 1})
df['ring_number'] = df['ring_number'].map({'one': 1, 'two': 2, 'null':0})
df['gill_size'] = df['gill_size'].map({'broad': 1, 'narrow': 0})
df['gill_spacing'] = df['gill_spacing'].map({'close': 1, 'crowded': 0})
df['bruises'] = df['bruises'].map({'Bruises': 1, 'No presenta': 0})


df.head()
# Out:
#       class cap_shape cap_surface cap_color    odor  gill_attachment  \
# id
# 367       1      bell       scaly    yellow  almond                1
# 5123      0    convex      smooth       red    foul                1
# 2864      1    convex     fibrous     green    null                1
# 4674      0      flat      smooth     white    foul                1
# 1210      1    convex      smooth     white    null                1
#
#       gill_spacing  gill_size gill_color  stalk_shape  ...  \
# id                                                     ...
# 367              1          1      black            1  ...
# 5123             1          0       buff            0  ...
# 2864             1          1       pink            0  ...
# 4674             1          1       pink            0  ...
# 1210             0          1      black            0  ...
#
#      stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# id
# 367                   white                  white         1      white
# 5123                  white                   pink         1      white
# 2864                   pink                  white         1      white
# 4674                  white                  white         1      white
# 1210                  white                  white         1      white
#
#      ring_number   ring_type spore_print_color  population  habitat bruises
# id
# 367            1     pendant             brown   scattered  grasses       1
# 5123           1  evanescent             white     several    paths       0
# 2864           1     pendant             brown     several     wood       1
# 4674           1     pendant         chocolate   scattered  grasses       1
# 1210           1  evanescent             black    abundant  grasses       0
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['class', 'cap_shape', 'cap_surface', 'cap_color', 'odor',
#        'gill_attachment', 'gill_spacing', 'gill_size', 'gill_color',
#        'stalk_shape', 'stalk_root', 'stalk_surface_above_ring',
#        'stalk_surface_below_ring', 'stalk_color_above_ring',
#        'stalk_color_below_ring', 'veil_type', 'veil_color', 'ring_number',
#        'ring_type', 'spore_print_color', 'population', 'habitat', 'bruises'],
#       dtype='object')

# %%
print(df['cap_shape'].unique())
print(df['cap_surface'].unique())
print(df['gill_color'].unique())
print(df['cap_color'].unique())
print(df['odor'].unique())
print(df['stalk_root'].unique())
print(df['stalk_surface_below_ring'].unique())
print(df['stalk_surface_above_ring'].unique())
print(df['stalk_color_below_ring'].unique())
print(df['stalk_color_above_ring'].unique())
print(df['veil_color'].unique())
print(df['spore_print_color'].unique())
print(df['ring_type'].unique())
print(df['population'].unique())
print(df['habitat'].unique())
# Out:
# ['bell' 'convex' 'flat' 'sunken' 'knobbed' 'c']
# ['scaly' 'smooth' 'fibrous']
# ['black' 'buff' 'pink' 'purple' 'chocolate' 'white' 'brown' 'gray' 'red'
#  'orange' 'yellow' 'green']
# ['yellow' 'red' 'green' 'white' 'brown' 'pink' 'cinnamon' 'buff' 'purple']
# ['almond' 'foul' 'null' 'spicy' 'creosote' 'anise' 'fishy' 'pungent'
#  'musty']
# ['club' '?' 'bulbous' 'equal' 'rooted']
# ['smooth' 'silky' 'fibrous' 'scaly']
# ['smooth' 'silky' 'fibrous' 'scaly']
# ['white' 'pink' 'gray' 'buff' 'brown' 'red' 'orange' 'cinnamon' 'yellow']
# ['white' 'pink' 'gray' 'red' 'buff' 'brown' 'orange' 'cinnamon' 'yellow']
# ['white' 'orange' 'brown' 'yellow']
# ['brown' 'white' 'chocolate' 'black' 'purple' 'buff' 'yellow' 'green'
#  'orange']
# ['pendant' 'evanescent' 'large' 'flaring' 'null']
# ['scattered' 'several' 'abundant' 'solitary' 'clustered' 'numerous']
# ['grasses' 'paths' 'wood' 'leaves' 'urban' 'waste' 'meadows']

# %%
# Crear un objeto LabelEncoder
le = LabelEncoder()

# Aplicar la codificación en cada columna categórica
df['cap_shape'] = le.fit_transform(df['cap_shape'])
df['cap_surface'] = le.fit_transform(df['cap_surface'])
df['gill_color'] = le.fit_transform(df['gill_color'])
df['cap_color'] = le.fit_transform(df['cap_color'])
df['odor'] = le.fit_transform(df['odor'])
df['stalk_root'] = le.fit_transform(df['stalk_root'])
df['stalk_surface_below_ring'] = le.fit_transform(df['stalk_surface_below_ring'])
df['stalk_surface_above_ring'] = le.fit_transform(df['stalk_surface_above_ring'])
df['stalk_color_below_ring'] = le.fit_transform(df['stalk_color_below_ring'])
df['stalk_color_above_ring'] = le.fit_transform(df['stalk_color_above_ring'])
df['veil_color'] = le.fit_transform(df['veil_color'])
df['spore_print_color'] = le.fit_transform(df['spore_print_color'])
df['ring_type'] = le.fit_transform(df['ring_type'])
df['population'] = le.fit_transform(df['population'])
df['habitat'] = le.fit_transform(df['habitat'])


df.head()
# Out:
#       class  cap_shape  cap_surface  cap_color  odor  gill_attachment  \
# id
# 367       1          0            1          8     0                1
# 5123      0          2            2          6     4                1
# 2864      1          2            0          3     6                1
# 4674      0          3            2          7     4                1
# 1210      1          2            2          7     6                1
#
#       gill_spacing  gill_size  gill_color  stalk_shape  ...  \
# id                                                      ...
# 367              1          1           0            1  ...
# 5123             1          0           2            0  ...
# 2864             1          1           7            0  ...
# 4674             1          1           7            0  ...
# 1210             0          1           0            0  ...
#
#       stalk_color_above_ring  stalk_color_below_ring  veil_type  veil_color  \
# id
# 367                        7                       7          1           2
# 5123                       7                       5          1           2
# 2864                       5                       7          1           2
# 4674                       7                       7          1           2
# 1210                       7                       7          1           2
#
#       ring_number  ring_type  spore_print_color  population  habitat  bruises
# id
# 367             1          4                  1           3        0        1
# 5123            1          0                  7           4        3        0
# 2864            1          4                  1           4        6        1
# 4674            1          4                  3           3        0        1
# 1210            1          0                  0           0        0        0
#
# [5 rows x 23 columns]
